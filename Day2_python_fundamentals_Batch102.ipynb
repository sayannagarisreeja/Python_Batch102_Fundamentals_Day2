# %%
a=2
b=7
c=a+b
print(c)
# Out:
# 9

# %%
#...rules for declarng the varaibles :.....?

# %%
rule-1: No namespaces for declaring the variables

# %%
first name="ramya"
print(first name)
# Out:
#   Cell In[2], line 1
#     first name="ramya"
#           ^
# SyntaxError: invalid syntax

# %%
first_name="ramya"
print(first_name)
# Out:
# ramya

# %% [markdown]
# rule-2: a variable name should not contain any special character

# %%
@name="ajay"
print(@name)
# Out:
#   Cell In[4], line 1
#     @name="ajay"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
name="ajay"
print(name)
# Out:
# ajay

# %% [raw]
# rule-3: in a variable we cannot start with a numbers

# %%
1name="sreeja"
print(1name)
# Out:
#   Cell In[7], line 1
#     1name="sreeja"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1="sreeja"
print(name1)
# Out:
# sreeja

# %%
# string classification types......?

# %%
name1='sreeja'   #....single quote..
print(name1)
# Out:
# sreeja

# %%
name2="sreeja" #......double quote..
print(name2)
# Out:
# sreeja

# %%
#...string methods....

# %%
type(name)
# Out:
# str

# %%
type(name1)
# Out:
# str

# %%
fullname="Sayannagari sreeja"
print(fullname)
# Out:
# Sayannagari sreeja

# %%
fullname="sayannagari sreeja"
print(fullname.title())     #.......we can use the title to change the first letter should be capital...
# Out:
# Sayannagari Sreeja
